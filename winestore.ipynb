# %%
import traceback
import requests
from bs4 import BeautifulSoup
from slugify import slugify

from urllib3.exceptions import InsecureRequestWarning

from library.db_inserter import sites_inserter, product_inserter
from library.img_parser import image_name_parser, upload_image
from library.library import send_slack_notification, log_printer, requests_get, notification_lite

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Language': 'en-US,en;q=0.9',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'If-Modified-Since': 'Mon, 19 Sep 2022 08:00:46 GMT',
    'Referer': 'https://winestore.jp/',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
    'sec-ch-ua': '"Google Chrome";v="105", "Not)A;Brand";v="8", "Chromium";v="105"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

# %%
def get_site_details() :
    response = requests.get('https://winestore.jp', headers=headers)
    site_soup = BeautifulSoup(response.text, 'html.parser')
    try:
        site=[]
        # original store name Wassy'sについて
        store_name = "Online Wassy's"
        language = site_soup.find('html')['lang']
        site_details = {
            'url': 'https://winestore.jp',
            'name': store_name,
            'seo_name': slugify(store_name),
            'country_code':['JP'],
            'market': ['ja'],
            'language': [language],
        }
        site.append(site_details)
        return site
    except:
        pass

# %%
def get_max_page():
    response = requests_get('https://winestore.jp/c/gr411', headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    max_page = int(soup.find('div', class_='fs-c-pagination').find_all('a')[-2].text)
    return max_page + 1

# %%
def get_product_data(link):
    product_response = requests_get(f"https://winestore.jp{link}", headers=headers)
    product_soup = BeautifulSoup(product_response.text, 'html.parser')
    item = {
        'product_url' : f"https://winestore.jp{link}",
        'tax_included' : True,
        'category' : 'wine'
    }

    # image
    try:
        main_img_url =  product_soup.find('div','fs-c-productMainImage__image').find('img')['src']
        main_img_name = main_img_url.split('/')[-1].split('?')[0]
        main_img_url = f"https://static.millesima.com/s3/attachements/h531px/{main_img_name}.png"
        item['image_url'] = [main_img_url]
        item['image_bucket'] = [image_name_parser(main_img_name, FOLDER_NAME)]
    except:
        pass


    try:
        # item['name_en'] = 'Kimura Cellars Sauvignon Blanc Marlborough Home Block Vineyard [2022]'
        item['name'] = product_soup.find('span', class_='fs-c-productNameHeading__name').get_text(strip=True)
        item['seo_name'] = slugify(product_soup.find('span', class_='fs-c-productNameHeading__name').get_text(strip=True))
        item['description'] = product_soup.find('div',class_='fs-p-productDescription fs-p-productDescription--full').get_text(strip=True)
    except Exception as e:
        print(e)
        pass

    try:
        item['sku'] = product_soup.find('span', class_='fs-c-productNumber__number').text
    except:
        pass

    try:
        for table_data in product_soup.find('table', class_='productSpec_Tbl').find_all('tr'):
            if '生産者' in table_data.find('th').text:
                item['winery'] = table_data.find('td').text
            elif '生産年' in table_data.find('th').text:
                item['vintage'] = table_data.find('td').text
            elif 'タイプ' in table_data.find('th').text:
                item['taste'] = table_data.find('td').find_all('span')[-1].get_text(strip=True).split(' ')[1]
                item['product_type'] = table_data.find('td').find_all('span')[0].text.split(' ')[1]
            elif '生産地' in table_data.find('th').text:
                item['country_origin'] = table_data.find('td').text.split('/')[0]
                item['region'] = table_data.find('td').text.split('/')[1]

    except:
        pass

    # reviews

    try:
        reviews = []
        for table_data in product_soup.find('table', class_='productSpec_Tbl').find_all('tr'):
            if '評価・得点' in table_data.find('th').text:
                for review_data in table_data.find('td').find_all('span'):
                    try:
                        review = {
                            'reviewer_name': review_data.text.split('：')[0],
                            'review_score': float(review_data.text.split('：')[1].replace('点','').replace('+','').replace('、','')) / 20 ,
                        }
                        reviews.append(review)
                    except:
                        for review_split in review_data.get_text(strip=True).split('、'):
                            review = {
                                'reviewer_name': review_split.split('：')[0],
                                'review_score': float(review_split.split('：')[1].replace('点','').replace('+','').replace('、','')) / 20 ,
                            }
                            reviews.append(review)
        item['reviews'] = reviews
    except:
        pass

    # price
    try:
        prices = []
        price = {
            'format' : 'bottle',
            'currency' : 'JPY'
        }

        if product_soup.find('div', class_='fs-c-productPrice fs-c-productPrice--listed'):
            price['package_price'] = product_soup.find('span', class_='fs-c-productPrice__main__price fs-c-price').get_text(strip=True).replace('¥','').replace(',','')
            price['unit_price'] = product_soup.find('span', class_='fs-c-productPrice__main__price fs-c-price').get_text(strip=True).replace('¥','').replace(',','')

            price['package_discounted_price'] = product_soup.find('div', class_='fs-c-productPrice fs-c-productPrice--selling').find('span',class_='fs-c-productPrice__main__price fs-c-price').get_text(strip=True).replace('¥','').replace(',','')
            price['unit_discounted_price'] = product_soup.find('div', class_='fs-c-productPrice fs-c-productPrice--selling').find('span',class_='fs-c-productPrice__main__price fs-c-price').get_text(strip=True).replace('¥','').replace(',','')
        else:
            try:
                price['package_price'] = product_soup.find('span',class_='fs-c-productPrice__main__price fs-c-price').get_text(strip=True).replace('¥','').replace(',','')
                price['unit_price'] = product_soup.find('span',class_='fs-c-productPrice__main__price fs-c-price').get_text(strip=True).replace('¥','').replace(',','')
            except:
                pass

        try:
            for table_data in product_soup.find('table', class_='productSpec_Tbl').find_all('tr'):
                if '容量' in table_data.find('th').text:
                    price['format_size'] = table_data.find('td').text
        except Exception as e:
            print(e)
            pass

        try:
            price['stock'] = product_soup.find('div', class_='fs-c-productStock').get_text(strip=True).split(' in')[0].replace('在庫数','')
        except:
            pass
        prices.append(price)
        item['prices'] = prices
    except:
        pass

    return item

# %%
if __name__ == "__main__":
    site_data = {
        'url': 'https://winestore.jp/',
        'name': "Wassy'sについて",
        'country_code': 'JP',
        'market': ['JP'],
        'language': ['ja'],
    }
    try:
        OUTPUT = []
        FOLDER_NAME = 'winestore_img'
        max_page = get_max_page()
        for page in range(1, max_page + 1):
            params = {
                'page': page,
                'sort': 'latest',
            }
            response = requests.get('https://winestore.jp/c/gr411', params=params, headers=headers)
            page_soup = BeautifulSoup(response.text, 'html.parser')

            for product in page_soup.find('div', class_='fs-c-productList__list').find_all('article',class_='fs-c-productList__list__item fs-c-productListItem'):
                link = product.find('h2').find('a')['href']
                OUTPUT.append(get_product_data(link))

        sites_inserter(site_data)
        product_inserter(OUTPUT, site_data)

        # upload_image(FOLDER_NAME)
        # notification_lite(f'{len(OUTPUT)} rows inserted/updated', site_data['name'])
    except Exception as e:
        # notification_lite("Scraping failed", site_data['name'])
        traceback.print_exc()
# Out:
# 4660 : 2022-10-10 22:32:13.874337 : status_code: 200, RTT: 1.125897, url: https://winestore.jp/c/gr411
# 4660 : 2022-10-10 22:32:16.452429 : status_code: 200, RTT: 1.146112, url: https://winestore.jp/c/item200/item216/item218/73257
# 4660 : 2022-10-10 22:32:17.745022 : status_code: 200, RTT: 1.158103, url: https://winestore.jp/c/item1/item920/item12/73256
# 4660 : 2022-10-10 22:32:18.668121 : status_code: 200, RTT: 0.778001, url: https://winestore.jp/c/item1/item920/item13/73255
# 4660 : 2022-10-10 22:32:19.564444 : status_code: 200, RTT: 0.730269, url: https://winestore.jp/c/item200/item236/item237/73254
# 4660 : 2022-10-10 22:32:20.480310 : status_code: 200, RTT: 0.751031, url: https://winestore.jp/c/item500/item506/item507/73235
# 4660 : 2022-10-10 22:32:21.497380 : status_code: 200, RTT: 0.75932, url: https://winestore.jp/c/item500/item506/item507/73234
# 4660 : 2022-10-10 22:32:22.555301 : status_code: 200, RTT: 0.816158, url: https://winestore.jp/c/item500/item506/item507/73233
# 4660 : 2022-10-10 22:32:23.462761 : status_code: 200, RTT: 0.753311, url: https://winestore.jp/c/item500/item506/item507/73232
# 4660 : 2022-10-10 22:32:24.431517 : status_code: 200, RTT: 0.747771, url: https://winestore.jp/c/item200/item216/item220/73231
# 4660 : 2022-10-10 22:32:25.359862 : status_code: 200, RTT: 0.764255, url: https://winestore.jp/c/item1/item920/item12/73230
# 4660 : 2022-10-10 22:32:26.257669 : status_code: 200, RTT: 0.746104, url: https://winestore.jp/c/item1/item920/item12/73229
# 4660 : 2022-10-10 22:32:27.129905 : status_code: 200, RTT: 0.737429, url: https://winestore.jp/c/item1/item920/item12/73228
# 4660 : 2022-10-10 22:32:28.253086 : status_code: 200, RTT: 1.000027, url: https://winestore.jp/c/item1/item2/item3/73227
# 4660 : 2022-10-10 22:32:29.126133 : status_code: 200, RTT: 0.752554, url: https://winestore.jp/c/item1/item920/item12/73226
# 4660 : 2022-10-10 22:32:30.024161 : status_code: 200, RTT: 0.780293, url: https://winestore.jp/c/item100/item101/item105/73225
# 4660 : 2022-10-10 22:32:30.863004 : status_code: 200, RTT: 0.72792, url: https://winestore.jp/c/item100/item101/item102/73224
# 4660 : 2022-10-10 22:32:31.698551 : status_code: 200, RTT: 0.718577, url: https://winestore.jp/c/item100/item101/item102/73223
# 4660 : 2022-10-10 22:32:33.150978 : status_code: 200, RTT: 1.194064, url: https://winestore.jp/c/item1/item2/item3/73222
# 4660 : 2022-10-10 22:32:34.132229 : status_code: 200, RTT: 0.743459, url: https://winestore.jp/c/item300/item306/item308/73221
# 4660 : 2022-10-10 22:32:35.069820 : status_code: 200, RTT: 0.72803, url: https://winestore.jp/c/item1/item920/item15/73220
# 4660 : 2022-10-10 22:32:39.054532 : status_code: 200, RTT: 2.444301, url: https://winestore.jp/c/item300/item306/item308/73219
# 4660 : 2022-10-10 22:32:41.354115 : status_code: 200, RTT: 1.602769, url: https://winestore.jp/c/item300/item306/item307/73218
# 4660 : 2022-10-10 22:32:43.432220 : status_code: 200, RTT: 0.984241, url: https://winestore.jp/c/item300/item306/item307/73217
# 4660 : 2022-10-10 22:32:45.113891 : status_code: 200, RTT: 1.198961, url: https://winestore.jp/c/item200/item231/item233/73216
# 4660 : 2022-10-10 22:32:46.642091 : status_code: 200, RTT: 1.263925, url: https://winestore.jp/c/item300/item311/item314/73215
# 4660 : 2022-10-10 22:32:47.887108 : status_code: 200, RTT: 0.875235, url: https://winestore.jp/c/item100/item101/item103/73214
# 4660 : 2022-10-10 22:32:49.217135 : status_code: 200, RTT: 0.796274, url: https://winestore.jp/c/item1/item2/item3/73213
# 4660 : 2022-10-10 22:32:50.846662 : status_code: 200, RTT: 1.45439, url: https://winestore.jp/c/item1/item920/item13/73212
# 4660 : 2022-10-10 22:32:52.189469 : status_code: 200, RTT: 1.123097, url: https://winestore.jp/c/item1/item920/item12/73211
# 4660 : 2022-10-10 22:32:53.420308 : status_code: 200, RTT: 0.930417, url: https://winestore.jp/c/item1/item7/item8/73210
# 4660 : 2022-10-10 22:33:00.375133 : status_code: 200, RTT: 6.363801, url: https://winestore.jp/c/item1/item2/item3/73209
# 4660 : 2022-10-10 22:33:01.697744 : status_code: 200, RTT: 1.085361, url: https://winestore.jp/c/item1/item2/item4/73208
# 4660 : 2022-10-10 22:33:02.565933 : status_code: 200, RTT: 0.763785, url: https://winestore.jp/c/item1/item2/item4/73207
# 4660 : 2022-10-10 22:33:03.436107 : status_code: 200, RTT: 0.760026, url: https://winestore.jp/c/item1/item920/item13/73206
# 4660 : 2022-10-10 22:33:04.314103 : status_code: 200, RTT: 0.749323, url: https://winestore.jp/c/item1/item920/item12/73205
# 4660 : 2022-10-10 22:33:05.353787 : status_code: 200, RTT: 0.8054, url: https://winestore.jp/c/item1/item920/item13/73204
# 4660 : 2022-10-10 22:33:06.286607 : status_code: 200, RTT: 0.758512, url: https://winestore.jp/c/item1/item7/item9/73203
# 4660 : 2022-10-10 22:33:07.634522 : status_code: 200, RTT: 1.208432, url: https://winestore.jp/c/item1/item2/item3/73202
# 4660 : 2022-10-10 22:33:08.541769 : status_code: 200, RTT: 0.72222, url: https://winestore.jp/c/item200/item216/item218/73201
# 4660 : 2022-10-10 22:33:09.491458 : status_code: 200, RTT: 0.747035, url: https://winestore.jp/c/item200/item216/item218/73200
# 4660 : 2022-10-10 22:33:13.964963 : status_code: 200, RTT: 3.092638, url: https://winestore.jp/c/item1/item2/item3/72033
# 4660 : 2022-10-10 22:33:14.994563 : status_code: 200, RTT: 0.743769, url: https://winestore.jp/c/item1/item2/item4/72032
# 4660 : 2022-10-10 22:33:15.941977 : status_code: 200, RTT: 0.747641, url: https://winestore.jp/c/item300/item301/item302/72248
# 4660 : 2022-10-10 22:33:17.062463 : status_code: 200, RTT: 0.770695, url: https://winestore.jp/c/item1/item2/item3/72195
# 4660 : 2022-10-10 22:33:18.031895 : status_code: 200, RTT: 0.749411, url: https://winestore.jp/c/item1/item2/item3/69694
# 4660 : 2022-10-10 22:33:19.617200 : status_code: 200, RTT: 1.406956, url: https://winestore.jp/c/item1100/item1101/item1106/67949
# 4660 : 2022-10-10 22:33:21.534706 : status_code: 200, RTT: 1.726431, url: https://winestore.jp/c/item300/item311/item312/67948
# 4660 : 2022-10-10 22:33:22.393702 : status_code: 200, RTT: 0.73783, url: https://winestore.jp/c/item300/item311/item312/67946
# 4660 : 2022-10-10 22:33:23.242921 : status_code: 200, RTT: 0.723461, url: https://winestore.jp/c/item300/item311/item312/67945
# 4660 : 2022-10-10 22:33:24.220584 : status_code: 200, RTT: 0.802643, url: https://winestore.jp/c/item300/item311/item312/67944
# 4660 : 2022-10-10 22:33:25.152470 : status_code: 200, RTT: 0.741156, url: https://winestore.jp/c/item300/item306/item307/67942
# 4660 : 2022-10-10 22:33:26.075557 : status_code: 200, RTT: 0.804448, url: https://winestore.jp/c/item300/item301/item302/67940
# 4660 : 2022-10-10 22:33:27.048424 : status_code: 200, RTT: 0.768831, url: https://winestore.jp/c/item300/item301/item302/67932
# 4660 : 2022-10-10 22:33:29.322225 : status_code: 200, RTT: 1.509404, url: https://winestore.jp/c/item200/item236/item238/67670
# 4660 : 2022-10-10 22:33:30.379225 : status_code: 200, RTT: 0.765614, url: https://winestore.jp/c/item300/item301/item303/66021
# 4660 : 2022-10-10 22:33:31.886101 : status_code: 200, RTT: 1.295671, url: https://winestore.jp/c/item300/item311/item312/65998
# 4660 : 2022-10-10 22:33:32.927102 : status_code: 200, RTT: 0.763868, url: https://winestore.jp/c/item300/item311/item312/65987
# 4660 : 2022-10-10 22:33:33.884090 : status_code: 200, RTT: 0.786937, url: https://winestore.jp/c/item300/item301/item305/64056
# 4660 : 2022-10-10 22:33:34.860091 : status_code: 200, RTT: 0.811085, url: https://winestore.jp/c/item200/item216/item218/61919
# 4660 : 2022-10-10 22:33:36.484457 : status_code: 200, RTT: 1.427715, url: https://winestore.jp/c/item300/item311/item313/61645
# 4660 : 2022-10-10 22:33:39.783881 : status_code: 200, RTT: 0.81657, url: https://winestore.jp/c/item300/item301/item305/60248
# 4660 : 2022-10-10 22:33:40.662111 : status_code: 200, RTT: 0.751545, url: https://winestore.jp/c/item300/item301/item302/59616
# 4660 : 2022-10-10 22:33:41.579562 : status_code: 200, RTT: 0.784662, url: https://winestore.jp/c/item200/item236/item238/57740
# 4660 : 2022-10-10 22:33:42.455776 : status_code: 200, RTT: 0.752329, url: https://winestore.jp/c/item200/item236/item237/57738
# 4660 : 2022-10-10 22:33:43.309263 : status_code: 200, RTT: 0.732125, url: https://winestore.jp/c/item300/item311/item312/56327
# 4660 : 2022-10-10 22:33:44.198144 : status_code: 200, RTT: 0.761183, url: https://winestore.jp/c/item300/item306/item307/56326
# 4660 : 2022-10-10 22:33:45.116762 : status_code: 200, RTT: 0.749344, url: https://winestore.jp/c/item300/item306/item307/55369
# 4660 : 2022-10-10 22:33:46.038771 : status_code: 200, RTT: 0.766766, url: https://winestore.jp/c/item300/item306/item308/55365
# 4660 : 2022-10-10 22:33:46.946582 : status_code: 200, RTT: 0.781167, url: https://winestore.jp/c/item300/item301/item303/55287
# 4660 : 2022-10-10 22:33:47.883477 : status_code: 200, RTT: 0.805818, url: https://winestore.jp/c/item300/item301/item302/54191
# 4660 : 2022-10-10 22:33:48.801405 : status_code: 200, RTT: 0.725788, url: https://winestore.jp/c/item300/item311/item312/54187
# 4660 : 2022-10-10 22:33:49.689102 : status_code: 200, RTT: 0.770269, url: https://winestore.jp/c/item300/item311/item312/54184
# 4660 : 2022-10-10 22:33:50.550298 : status_code: 200, RTT: 0.735785, url: https://winestore.jp/c/item300/item306/item308/54170
# 4660 : 2022-10-10 22:33:51.389625 : status_code: 200, RTT: 0.7295, url: https://winestore.jp/c/item200/item236/item238/54084
# 4660 : 2022-10-10 22:33:52.237229 : status_code: 200, RTT: 0.737767, url: https://winestore.jp/c/item300/item301/item303/54051
# 4660 : 2022-10-10 22:33:53.470299 : status_code: 200, RTT: 0.886085, url: https://winestore.jp/c/item300/item301/item303/54037
# 4660 : 2022-10-10 22:33:54.392637 : status_code: 200, RTT: 0.751835, url: https://winestore.jp/c/item300/item301/item305/54009
# 4660 : 2022-10-10 22:33:55.287187 : status_code: 200, RTT: 0.770746, url: https://winestore.jp/c/item300/item301/item302/53936
# 4660 : 2022-10-10 22:33:56.193626 : status_code: 200, RTT: 0.762129, url: https://winestore.jp/c/item300/item311/item312/53918
# 4660 : 2022-10-10 22:33:57.195372 : status_code: 200, RTT: 0.756927, url: https://winestore.jp/c/item300/item311/item312/53916
# 4660 : 2022-10-10 22:33:59.359863 : status_code: 200, RTT: 0.803124, url: https://winestore.jp/c/item1/item920/item12/53899
# 4660 : 2022-10-10 22:34:00.239559 : status_code: 200, RTT: 0.758442, url: https://winestore.jp/c/item100/item101/item102/53877
# 4660 : 2022-10-10 22:34:01.437853 : status_code: 200, RTT: 1.005372, url: https://winestore.jp/c/item1/item920/item12/51582
# 4660 : 2022-10-10 22:34:02.696560 : status_code: 200, RTT: 0.796861, url: https://winestore.jp/c/item300/item306/item307/51017
# 4660 : 2022-10-10 22:34:04.004568 : status_code: 200, RTT: 0.748277, url: https://winestore.jp/c/item300/item311/item312/49373
# 4660 : 2022-10-10 22:34:05.195999 : status_code: 200, RTT: 0.735013, url: https://winestore.jp/c/item300/item306/item308/48609
# 4660 : 2022-10-10 22:34:06.364614 : status_code: 200, RTT: 0.941991, url: https://winestore.jp/c/item1/item7/item8/73151
# 4660 : 2022-10-10 22:34:07.452505 : status_code: 200, RTT: 0.751014, url: https://winestore.jp/c/item200/item236/item238/73150
# 4660 : 2022-10-10 22:34:08.444732 : status_code: 200, RTT: 0.84232, url: https://winestore.jp/c/item200/item236/item237/73149
# 4660 : 2022-10-10 22:34:09.351299 : status_code: 200, RTT: 0.76598, url: https://winestore.jp/c/item200/item236/item237/73148
# 4660 : 2022-10-10 22:34:10.254821 : status_code: 200, RTT: 0.772202, url: https://winestore.jp/c/item200/item236/item237/73147
# 4660 : 2022-10-10 22:34:11.140802 : status_code: 200, RTT: 0.735363, url: https://winestore.jp/c/item200/item236/item238/73146
# 4660 : 2022-10-10 22:34:12.021578 : status_code: 200, RTT: 0.751688, url: https://winestore.jp/c/item1/item2/item3/73145
# 4660 : 2022-10-10 22:34:13.057581 : status_code: 200, RTT: 0.811119, url: https://winestore.jp/c/item1/item2/item3/73144
# 4660 : 2022-10-10 22:34:13.933209 : status_code: 200, RTT: 0.747229, url: https://winestore.jp/c/item1/item2/item3/73143
# 4660 : 2022-10-10 22:34:14.834506 : status_code: 200, RTT: 0.769455, url: https://winestore.jp/c/item1/item2/item3/73142
# 4660 : 2022-10-10 22:34:15.781969 : status_code: 200, RTT: 0.740038, url: https://winestore.jp/c/item1/item920/item13/73141
# 4660 : 2022-10-10 22:34:16.643186 : status_code: 200, RTT: 0.758188, url: https://winestore.jp/c/item1/item7/item9/73137
# 4660 : 2022-10-10 22:34:17.520096 : status_code: 200, RTT: 0.751608, url: https://winestore.jp/c/item1/item7/item8/73136
# 4660 : 2022-10-10 22:34:18.454140 : status_code: 200, RTT: 0.814361, url: https://winestore.jp/c/item1/item2/item3/73135
# 4660 : 2022-10-10 22:34:20.550598 : status_code: 200, RTT: 0.738692, url: https://winestore.jp/c/item1/item920/item12/73134
# 4660 : 2022-10-10 22:34:21.468760 : status_code: 200, RTT: 0.783906, url: https://winestore.jp/c/item1/item2/item4/73133
# 4660 : 2022-10-10 22:34:22.448150 : status_code: 200, RTT: 0.839957, url: https://winestore.jp/c/item1/item2/item4/73132
# 4660 : 2022-10-10 22:34:24.032330 : status_code: 200, RTT: 1.347009, url: https://winestore.jp/c/item1/item2/item3/73131
# 4660 : 2022-10-10 22:34:25.225139 : status_code: 200, RTT: 0.77547, url: https://winestore.jp/c/item1/item920/item12/73130
# 4660 : 2022-10-10 22:34:26.361815 : status_code: 200, RTT: 0.949288, url: https://winestore.jp/c/item1/item920/item12/73129
# 4660 : 2022-10-10 22:34:27.246877 : status_code: 200, RTT: 0.745028, url: https://winestore.jp/c/item1/item920/item12/73128
# 4660 : 2022-10-10 22:34:28.171513 : status_code: 200, RTT: 0.802026, url: https://winestore.jp/c/item1/item920/item13/73127
# 4660 : 2022-10-10 22:34:29.046948 : status_code: 200, RTT: 0.750256, url: https://winestore.jp/c/item1/item920/item12/73126
# 4660 : 2022-10-10 22:34:29.954421 : status_code: 200, RTT: 0.782803, url: https://winestore.jp/c/item1/item7/item8/73125
# 4660 : 2022-10-10 22:34:30.856420 : status_code: 200, RTT: 0.775096, url: https://winestore.jp/c/item1/item920/item13/73124
# 4660 : 2022-10-10 22:34:31.805306 : status_code: 200, RTT: 0.838683, url: https://winestore.jp/c/item1/item2/item4/73123
# 4660 : 2022-10-10 22:34:33.354271 : status_code: 200, RTT: 1.427583, url: https://winestore.jp/c/item1/item2/item3/73122
# 4660 : 2022-10-10 22:34:34.452967 : status_code: 200, RTT: 0.914743, url: https://winestore.jp/c/item1/item920/item13/73121
# 4660 : 2022-10-10 22:34:35.398332 : status_code: 200, RTT: 0.813256, url: https://winestore.jp/c/item1/item920/item13/73120
# 4660 : 2022-10-10 22:34:36.659181 : status_code: 200, RTT: 0.947429, url: https://winestore.jp/c/item1/item920/item15/73119
# 4660 : 2022-10-10 22:34:37.976816 : status_code: 200, RTT: 0.904359, url: https://winestore.jp/c/item1/item920/item12/73118
# 4660 : 2022-10-10 22:34:39.952795 : status_code: 200, RTT: 1.330672, url: https://winestore.jp/c/item1/item920/item15/73117
# 4660 : 2022-10-10 22:34:40.963552 : status_code: 200, RTT: 0.831423, url: https://winestore.jp/c/item1/item920/item13/73116
# 4660 : 2022-10-10 22:34:42.084709 : status_code: 200, RTT: 0.866894, url: https://winestore.jp/c/item1/item7/item8/73252
# 4660 : 2022-10-10 22:34:44.582193 : status_code: 200, RTT: 0.864506, url: https://winestore.jp/c/item200/item216/item217/73251
# 4660 : 2022-10-10 22:34:46.659511 : status_code: 200, RTT: 1.394544, url: https://winestore.jp/c/item200/item216/item218/73250
# 4660 : 2022-10-10 22:34:48.167289 : status_code: 200, RTT: 0.902151, url: https://winestore.jp/c/item1/item920/item12/73249
# 4660 : 2022-10-10 22:34:51.863767 : status_code: 200, RTT: 2.667573, url: https://winestore.jp/c/item1/item920/item13/73248
# 4660 : 2022-10-10 22:34:55.211948 : status_code: 200, RTT: 2.771744, url: https://winestore.jp/c/item1/item7/item8/73247
# 4660 : 2022-10-10 22:34:56.887756 : status_code: 200, RTT: 1.256454, url: https://winestore.jp/c/item300/item301/item302/73246
# 4660 : 2022-10-10 22:34:58.834571 : status_code: 200, RTT: 1.16437, url: https://winestore.jp/c/item1/item2/item3/73245
# 4660 : 2022-10-10 22:35:00.560451 : status_code: 200, RTT: 1.132369, url: https://winestore.jp/c/item1/item2/item3/73244
# 4660 : 2022-10-10 22:35:01.873982 : status_code: 200, RTT: 0.98714, url: https://winestore.jp/c/item1/item2/item3/73243
# 4660 : 2022-10-10 22:35:03.138716 : status_code: 200, RTT: 0.795397, url: https://winestore.jp/c/item1/item920/item12/73242
# 4660 : 2022-10-10 22:35:05.109265 : status_code: 200, RTT: 0.960819, url: https://winestore.jp/c/item1/item920/item12/73241
# 4660 : 2022-10-10 22:35:06.173910 : status_code: 200, RTT: 0.832576, url: https://winestore.jp/c/item200/item216/item218/73240
# 4660 : 2022-10-10 22:35:07.262173 : status_code: 200, RTT: 0.9434, url: https://winestore.jp/c/item1/item2/item3/73239
# 4660 : 2022-10-10 22:35:08.161354 : status_code: 200, RTT: 0.745301, url: https://winestore.jp/c/item1/item920/item12/72772
# 4660 : 2022-10-10 22:35:09.096540 : status_code: 200, RTT: 0.778728, url: https://winestore.jp/c/item1/item920/item12/72771
# 4660 : 2022-10-10 22:35:10.104498 : status_code: 200, RTT: 0.846797, url: https://winestore.jp/c/item1/item920/item14/72767
# 4660 : 2022-10-10 22:35:11.002875 : status_code: 200, RTT: 0.760241, url: https://winestore.jp/c/item1/item2/item3/72764
# 4660 : 2022-10-10 22:35:11.955335 : status_code: 200, RTT: 0.7866, url: https://winestore.jp/c/item1/item920/item12/72756
# 4660 : 2022-10-10 22:35:13.614927 : status_code: 200, RTT: 1.238452, url: https://winestore.jp/c/item1/item2/item3/72504
# 4660 : 2022-10-10 22:35:14.729958 : status_code: 200, RTT: 0.886274, url: https://winestore.jp/c/item1/item2/item3/72502
# 4660 : 2022-10-10 22:35:17.130689 : status_code: 200, RTT: 0.82359, url: https://winestore.jp/c/item1/item7/item8/72501
# 4660 : 2022-10-10 22:35:18.050551 : status_code: 200, RTT: 0.766623, url: https://winestore.jp/c/item1/item920/item13/72498
# 4660 : 2022-10-10 22:35:19.418914 : status_code: 200, RTT: 1.015606, url: https://winestore.jp/c/item1/item920/item14/72497
# 4660 : 2022-10-10 22:35:20.464246 : status_code: 200, RTT: 0.86859, url: https://winestore.jp/c/item1/item920/item12/72491
# 4660 : 2022-10-10 22:35:21.398232 : status_code: 200, RTT: 0.769264, url: https://winestore.jp/c/item1/item920/item12/72490
# 4660 : 2022-10-10 22:35:22.373498 : status_code: 200, RTT: 0.793072, url: https://winestore.jp/c/item1/item920/item12/72489
# 4660 : 2022-10-10 22:35:23.276563 : status_code: 200, RTT: 0.736679, url: https://winestore.jp/c/item1/item2/item4/72487
# 4660 : 2022-10-10 22:35:24.584978 : status_code: 200, RTT: 0.913889, url: https://winestore.jp/c/item1/item920/item12/72486
# 4660 : 2022-10-10 22:35:25.691372 : status_code: 200, RTT: 0.828251, url: https://winestore.jp/c/item1/item920/item13/72485
# 4660 : 2022-10-10 22:35:26.678714 : status_code: 200, RTT: 0.795291, url: https://winestore.jp/c/item1/item2/item3/72482
# 4660 : 2022-10-10 22:35:27.622267 : status_code: 200, RTT: 0.750705, url: https://winestore.jp/c/item1/item2/item3/72471
# 4660 : 2022-10-10 22:35:29.146032 : status_code: 200, RTT: 0.896115, url: https://winestore.jp/c/item1/item920/item13/72468
# 4660 : 2022-10-10 22:35:30.291602 : status_code: 200, RTT: 0.840759, url: https://winestore.jp/c/item1/item2/item3/72466
# 4660 : 2022-10-10 22:35:31.468705 : status_code: 200, RTT: 0.804868, url: https://winestore.jp/c/item1/item2/item4/72465
# 4660 : 2022-10-10 22:35:32.534574 : status_code: 200, RTT: 0.836856, url: https://winestore.jp/c/item1/item2/item3/72464
# 4660 : 2022-10-10 22:35:34.379108 : status_code: 200, RTT: 1.076414, url: https://winestore.jp/c/item1/item920/item12/72453
# 4660 : 2022-10-10 22:35:36.662382 : status_code: 200, RTT: 1.78517, url: https://winestore.jp/c/item100/item101/item102/72452
# 4660 : 2022-10-10 22:35:38.100309 : status_code: 200, RTT: 0.892233, url: https://winestore.jp/c/item1/item920/item12/71474
# 4660 : 2022-10-10 22:35:39.755587 : status_code: 200, RTT: 1.00416, url: https://winestore.jp/c/item1/item920/item12/71473
# 4660 : 2022-10-10 22:35:41.217862 : status_code: 200, RTT: 1.047568, url: https://winestore.jp/c/item1/item920/item13/71471
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 19
#      14 params = {
#      15     'page': page,
#      16     'sort': 'latest',
#      17 }
#      18 response = requests.get('https://winestore.jp/c/gr411', params=params, headers=headers)
# ---> 19 page_soup = BeautifulSoup(response.text, 'html.parser')
#      21 for product in page_soup.find('div', class_='fs-c-productList__list').find_all('article',class_='fs-c-productList__list__item fs-c-productListItem'):
#      22     link = product.find('h2').find('a')['href']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\__init__.py:333, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331 self.builder.initialize_soup(self)
#     332 try:
# --> 333     self._feed()
#     334     success = True
#     335     break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\__init__.py:451, in BeautifulSoup._feed(self)
#     448 # Convert the document to Unicode.
#     449 self.builder.reset()
# --> 451 self.builder.feed(self.markup)
#     452 # Close out any unfinished strings and close all the open tags.
#     453 self.endData()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\builder\_htmlparser.py:399, in HTMLParserTreeBuilder.feed(self, markup)
#     397 parser.soup = self.soup
#     398 try:
# --> 399     parser.feed(markup)
#     400     parser.close()
#     401 except HTMLParseError as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\html\parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\html\parser.py:170, in HTMLParser.goahead(self, end)
#     168 if startswith('<', i):
#     169     if starttagopen.match(rawdata, i): # < + letter
# --> 170         k = self.parse_starttag(i)
#     171     elif startswith("</", i):
#     172         k = self.parse_endtag(i)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\html\parser.py:316, in HTMLParser.parse_starttag(self, i)
#     314 while k < endpos:
#     315     m = attrfind_tolerant.match(rawdata, k)
# --> 316     if not m:
#     317         break
#     318     attrname, rest, attrvalue = m.group(1, 2, 3)
#
# KeyboardInterrupt:
